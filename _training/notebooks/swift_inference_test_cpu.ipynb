// %%
%install '.package(url: "https://github.com/mxcl/Path.swift", from: "0.16.1")' Path
%install '.package(url: "https://github.com/JohnSundell/ShellOut.git", from: "2.0.0")' ShellOut
%install '.package(url: "https://github.com/IBM-Swift/SwiftyRequest.git", from: "2.0.6")' SwiftyRequest
%install '.package(url: "https://github.com/JustHTTP/Just", from: "0.7.1")' Just
%install '.package(url: "https://github.com/JohnSundell/Files.git", from: "3.1.0")' Files
%install '.package(url: "https://github.com/latenitesoft/NotebookExport", from: "0.5.0")' NotebookExport
%install '.package(url: "https://github.com/weichsel/ZIPFoundation/", .upToNextMajor(from: "0.9.0"))' ZIPFoundation
%include "EnableIPythonDisplay.swift"
IPythonDisplay.shell.enable_matplotlib("inline")
// Out:
// Installing packages:
// 	.package(url: "https://github.com/mxcl/Path.swift", from: "0.16.1")
// 		Path
// 	.package(url: "https://github.com/JohnSundell/ShellOut.git", from: "2.0.0")
// 		ShellOut
// 	.package(url: "https://github.com/IBM-Swift/SwiftyRequest.git", from: "2.0.6")
// 		SwiftyRequest
// 	.package(url: "https://github.com/JustHTTP/Just", from: "0.7.1")
// 		Just
// 	.package(url: "https://github.com/JohnSundell/Files.git", from: "3.1.0")
// 		Files
// 	.package(url: "https://github.com/latenitesoft/NotebookExport", from: "0.5.0")
// 		NotebookExport
// 	.package(url: "https://github.com/weichsel/ZIPFoundation/", .upToNextMajor(from: "0.9.0"))
// 		ZIPFoundation
// With SwiftPM flags: []
// Working in: /tmp/tmp3ppzpuc1/swift-install
// Fetching https://github.com/mxcl/Path.swift
// Fetching https://github.com/JohnSundell/ShellOut.git
// Fetching https://github.com/IBM-Swift/SwiftyRequest.git
// Fetching https://github.com/JustHTTP/Just
// Fetching https://github.com/JohnSundell/Files.git
// Fetching https://github.com/latenitesoft/NotebookExport
// Fetching https://github.com/weichsel/ZIPFoundation/
// Fetching https://github.com/IBM-Swift/CircuitBreaker.git
// Fetching https://github.com/IBM-Swift/LoggerAPI.git
// Fetching https://github.com/apple/swift-log.git
// Cloning https://github.com/weichsel/ZIPFoundation/
// Resolving https://github.com/weichsel/ZIPFoundation/ at 0.9.9
// Cloning https://github.com/mxcl/Path.swift
// Resolving https://github.com/mxcl/Path.swift at 0.16.3
// Cloning https://github.com/apple/swift-log.git
// Resolving https://github.com/apple/swift-log.git at 1.2.0
// Cloning https://github.com/JohnSundell/ShellOut.git
// Resolving https://github.com/JohnSundell/ShellOut.git at 2.2.0
// Cloning https://github.com/JustHTTP/Just
// Resolving https://github.com/JustHTTP/Just at 0.8.0
// Cloning https://github.com/IBM-Swift/CircuitBreaker.git
// Resolving https://github.com/IBM-Swift/CircuitBreaker.git at 5.0.3
// Cloning https://github.com/JohnSundell/Files.git
// Resolving https://github.com/JohnSundell/Files.git at 3.1.0
// Cloning https://github.com/IBM-Swift/LoggerAPI.git
// Resolving https://github.com/IBM-Swift/LoggerAPI.git at 1.9.0
// Cloning https://github.com/latenitesoft/NotebookExport
// Resolving https://github.com/latenitesoft/NotebookExport at 0.6.0
// Cloning https://github.com/IBM-Swift/SwiftyRequest.git
// Resolving https://github.com/IBM-Swift/SwiftyRequest.git at 2.2.1
// [1/9] Compiling ZIPFoundation Archive+Reading.swift
// /tmp/tmp3ppzpuc1/swift-install/package/.build/checkouts/ShellOut/Sources/ShellOut.swift:350:9: warning: 'launchPath' is deprecated: renamed to 'executableURL'
//         launchPath = "/bin/bash"
//         ^
// /tmp/tmp3ppzpuc1/swift-install/package/.build/checkouts/ShellOut/Sources/ShellOut.swift:350:9: note: use 'executableURL' instead
//         launchPath = "/bin/bash"
//         ^~~~~~~~~~
//         executableURL
// /tmp/tmp3ppzpuc1/swift-install/package/.build/checkouts/ShellOut/Sources/ShellOut.swift:386:9: warning: 'launch()' is deprecated: renamed to 'run'
//         launch()
//         ^
// /tmp/tmp3ppzpuc1/swift-install/package/.build/checkouts/ShellOut/Sources/ShellOut.swift:386:9: note: use 'run' instead
//         launch()
//         ^~~~~~
//         run
// [2/10] Merging module ShellOut
// [3/19] Compiling Path Path+FileManager.swift
// [4/19] Compiling Path Path+StringConvertibles.swift
// [5/19] Compiling Path Path+ls.swift
// [6/19] Compiling Path Extensions.swift
// [7/19] Compiling Path Path+Attributes.swift
// [8/19] Compiling Path Path+Codable.swift
// [9/19] Compiling Path Path+CommonDirectories.swift
// [15/20] Merging module ZIPFoundation
// [16/23] Compiling Logging Locks.swift
// [17/23] Compiling Logging LogHandler.swift
// [20/23] Compiling Path Path->Bool.swift
// [21/23] Compiling Path Path.swift
// [22/24] Merging module Path
// [23/25] Compiling Logging Logging.swift
// [24/26] Merging module Logging
// [25/30] Compiling NotebookExport DependencyDescription.swift
// [26/30] Compiling NotebookExport ExtensionUtils.swift
// [27/30] Compiling NotebookExport NotebookExport.swift
// [28/30] Compiling NotebookExport PackageManifest.swift
// [29/31] Merging module NotebookExport
// [30/32] Compiling Files Files.swift
// [31/33] Merging module Just
// [32/34] Compiling LoggerAPI Logger.swift
// [33/35] Merging module LoggerAPI
// [34/45] Compiling CircuitBreaker BreakerError.swift
// [35/46] Merging module Files
// [37/46] Compiling CircuitBreaker Bulkhead.swift
// [38/46] Compiling CircuitBreaker CircuitBreaker.swift
// [39/46] Compiling CircuitBreaker Collection.swift
// [40/46] Compiling CircuitBreaker Invocation.swift
// [41/46] Compiling CircuitBreaker Monitor.swift
// [42/46] Compiling CircuitBreaker MonitorCollection.swift
// [43/46] Compiling CircuitBreaker Snapshot.swift
// [44/46] Compiling CircuitBreaker Stats.swift
// [45/46] Compiling CircuitBreaker Utils.swift
// [46/47] Merging module CircuitBreaker
// [47/57] Compiling SwiftyRequest CodableExtensions.swift
// [48/57] Compiling SwiftyRequest HTTPMethod.swift
// [49/57] Compiling SwiftyRequest JSON.swift
// [50/57] Compiling SwiftyRequest JSONWrapper.swift
// [51/57] Compiling SwiftyRequest MultipartFormData.swift
// [52/57] Compiling SwiftyRequest RestRequest.swift
// /tmp/tmp3ppzpuc1/swift-install/package/.build/checkouts/SwiftyRequest/Sources/SwiftyRequest/RestRequest.swift:985:15: warning: 'NSURLAuthenticationMethodClientCertificate' is deprecated: swift-corelibs-foundation does not currently support certificate authentication.
//         case (NSURLAuthenticationMethodClientCertificate, baseHost):
//               ^
// /tmp/tmp3ppzpuc1/swift-install/package/.build/checkouts/SwiftyRequest/Sources/SwiftyRequest/RestRequest.swift:1012:15: warning: 'NSURLAuthenticationMethodServerTrust' is deprecated: swift-corelibs-foundation does not support methods of authentication that rely on the Darwin Security framework.
//         case (NSURLAuthenticationMethodServerTrust, baseHost):
//               ^
// [53/57] Compiling SwiftyRequest RestToken.swift
// /tmp/tmp3ppzpuc1/swift-install/package/.build/checkouts/SwiftyRequest/Sources/SwiftyRequest/RestRequest.swift:985:15: warning: 'NSURLAuthenticationMethodClientCertificate' is deprecated: swift-corelibs-foundation does not currently support certificate authentication.
//         case (NSURLAuthenticationMethodClientCertificate, baseHost):
//               ^
// /tmp/tmp3ppzpuc1/swift-install/package/.build/checkouts/SwiftyRequest/Sources/SwiftyRequest/RestRequest.swift:1012:15: warning: 'NSURLAuthenticationMethodServerTrust' is deprecated: swift-corelibs-foundation does not support methods of authentication that rely on the Darwin Security framework.
//         case (NSURLAuthenticationMethodServerTrust, baseHost):
//               ^
// [54/57] Compiling SwiftyRequest RestUtilities.swift
// /tmp/tmp3ppzpuc1/swift-install/package/.build/checkouts/SwiftyRequest/Sources/SwiftyRequest/RestRequest.swift:985:15: warning: 'NSURLAuthenticationMethodClientCertificate' is deprecated: swift-corelibs-foundation does not currently support certificate authentication.
//         case (NSURLAuthenticationMethodClientCertificate, baseHost):
//               ^
// /tmp/tmp3ppzpuc1/swift-install/package/.build/checkouts/SwiftyRequest/Sources/SwiftyRequest/RestRequest.swift:1012:15: warning: 'NSURLAuthenticationMethodServerTrust' is deprecated: swift-corelibs-foundation does not support methods of authentication that rely on the Darwin Security framework.
//         case (NSURLAuthenticationMethodServerTrust, baseHost):
//               ^
// [55/57] Compiling SwiftyRequest ResultExtension.swift
// /tmp/tmp3ppzpuc1/swift-install/package/.build/checkouts/SwiftyRequest/Sources/SwiftyRequest/RestRequest.swift:985:15: warning: 'NSURLAuthenticationMethodClientCertificate' is deprecated: swift-corelibs-foundation does not currently support certificate authentication.
//         case (NSURLAuthenticationMethodClientCertificate, baseHost):
//               ^
// /tmp/tmp3ppzpuc1/swift-install/package/.build/checkouts/SwiftyRequest/Sources/SwiftyRequest/RestRequest.swift:1012:15: warning: 'NSURLAuthenticationMethodServerTrust' is deprecated: swift-corelibs-foundation does not support methods of authentication that rely on the Darwin Security framework.
//         case (NSURLAuthenticationMethodServerTrust, baseHost):
//               ^
// [56/57] Compiling SwiftyRequest StringExtensions.swift
// /tmp/tmp3ppzpuc1/swift-install/package/.build/checkouts/SwiftyRequest/Sources/SwiftyRequest/RestRequest.swift:985:15: warning: 'NSURLAuthenticationMethodClientCertificate' is deprecated: swift-corelibs-foundation does not currently support certificate authentication.
//         case (NSURLAuthenticationMethodClientCertificate, baseHost):
//               ^
// /tmp/tmp3ppzpuc1/swift-install/package/.build/checkouts/SwiftyRequest/Sources/SwiftyRequest/RestRequest.swift:1012:15: warning: 'NSURLAuthenticationMethodServerTrust' is deprecated: swift-corelibs-foundation does not support methods of authentication that rely on the Darwin Security framework.
//         case (NSURLAuthenticationMethodServerTrust, baseHost):
//               ^
// [57/58] Merging module SwiftyRequest
// [58/59] Compiling jupyterInstalledPackages jupyterInstalledPackages.swift
// [59/60] Merging module jupyterInstalledPackages
// [60/60] Linking libjupyterInstalledPackages.so
// Initializing Swift...
// Installation complete!
// ('inline', 'module://ipykernel.pylab.backend_inline')

// %%
import Foundation
import Python
import SwiftyRequest
import Path
import Files
import ShellOut
import FoundationNetworking
import ZIPFoundation

// %%
try shellOut(to: "pip install pytorchcv")
// Out:
// "Requirement already satisfied: pytorchcv in /usr/local/lib/python3.6/dist-packages (0.0.51)\nRequirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from pytorchcv) (1.17.4)\nRequirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from pytorchcv) (2.21.0)\nRequirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->pytorchcv) (2019.9.11)\nRequirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->pytorchcv) (2.8)\nRequirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->pytorchcv) (3.0.4)\nRequirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->pytorchcv) (1.24.3)"

// %%
print(Folder.current)
// Out:
// Folder(name: content, path: /content/)

// %%
let warnings = Python.import("warnings")
warnings.filterwarnings("ignore")

let fastai = Python.import("fastai")
let fastai_vision = Python.import("fastai.vision") 
let transforms = fastai_vision.transform 
let ImageList = fastai_vision.ImageList
let models = fastai_vision.models 
let cnn_learner = fastai_vision.cnn_learner 
let metrics = fastai.metrics 
let accuracy = metrics.accuracy
let top_k_accuracy = metrics.top_k_accuracy 
let error_rate = metrics.error_rate
let gc = fastai.basics.gc 
let ClassificationInterpretation = fastai.train.ClassificationInterpretation
let sys = Python.import("sys")
let pytorchcv = Python.import("pytorchcv")
let model_provider = Python.import("pytorchcv.model_provider")
let ptcv_get_model = model_provider.get_model 
let plt = Python.import("matplotlib.pyplot")
let py_time = Python.import("time")

// %%
print(fastai.__version__)
// Out:
// 1.0.59

// %%
let fileManager = FileManager()

// %%
let test_data_zip = Path("/content/test_single.zip")!
fileManager.unzipItem(at: test_data_zip.url, to: Path("/content/")!.url)

// %%
let os = Python.import("os")
let test_files = Path("/content/test_single")!.url.path
let test_file_list = os.listdir(test_files)
let pd = Python.import("pandas")
let df = pd.DataFrame(test_file_list)
df
// Out:
//                                         0
// 0                 test_low_capacity_4.jpg
// 1                test_high_capacity_2.jpg
// 2    test_no_turbines_med_potential_2.jpg
// 3     test_no_turbines_no_potential_3.jpg
// 4                 test_low_capacity_8.jpg
// 5             test_medium_capacity_10.jpg
// 6   test_no_turbines_high_potential_1.jpg
// 7    test_no_turbines_med_potential_1.jpg
// 8                test_low_capacity_11.jpg
// 9                test_high_capacity_8.jpg
// 10            test_medium_capacity_12.jpg
// 11                test_low_capacity_3.jpg
// 12                test_low_capacity_5.jpg
// 13  test_no_turbines_high_potential_5.jpg
// 14    test_no_turbines_no_potential_4.jpg
// 15             test_medium_capacity_6.jpg
// 16  test_no_turbines_high_potential_9.jpg
// 17    test_no_turbines_no_potential_2.jpg
// 18            test_medium_capacity_11.jpg
// 19             test_medium_capacity_4.jpg
// 20               test_high_capacity_6.jpg
// 21             test_medium_capacity_2.jpg
// 22                test_low_capacity_6.jpg
// 23            test_medium_capacity_13.jpg
// 24   test_no_turbines_low_potential_1.jpg
// 25   test_no_turbines_high_capacity_7.jpg
// 26    test_no_turbines_no_potential_5.jpg
// 27               test_low_capacity_10.jpg
// 28             test_medium_capacity_5.jpg
// 29  test_no_turbines_high_potential_8.jpg
// 30                test_low_capacity_7.jpg
// 31               test_high_capacity_4.jpg
// 32             test_medium_capacity_7.jpg
// 33   test_no_turbines_low_potential_2.jpg
// 34               test_high_capacity_1.jpg
// 35                test_low_capacity_2.jpg
// 36  test_no_turbines_high_potential_2.jpg
// 37    test_no_turbines_no_potential_1.jpg
// 38               test_high_capacity_3.jpg
// 39                test_low_capacity_1.jpg
// 40               test_high_capacity_5.jpg
// 41                test_low_capacity_9.jpg
// 42   test_no_turbines_med_potential_3.jpg
// 43  test_no_turbines_high_potential_6.jpg
// 44             test_medium_capacity_1.jpg
// 45    test_no_turbines_no_potential_6.jpg
// 46               test_high_capacity_7.jpg
// 47             test_medium_capacity_8.jpg
// 48             test_medium_capacity_9.jpg

// %%
let inference_test_efficientnet = fastai_vision.load_learner.dynamicallyCall(withKeywordArguments: ["path": "/content/", "file":"effnet-b1-c98.pkl", "test": ImageList.from_folder("/content/test_single")])
let inference_test_inceptionv3 = fastai_vision.load_learner.dynamicallyCall(withKeywordArguments: ["path": "/content/", "file":"incept-v3-c95.pkl", "test": ImageList.from_folder("/content/test_single")])

// %%
inference_test_efficientnet.model.eval()
var eff_preds:[String:String] = [:]

//let start = DispatchTime.now(), 
let eff_start = py_time.time()
for img in 0...48 {
  var name = String(test_file_list[img])!
  var p = inference_test_efficientnet.predict(inference_test_efficientnet.data.test_dl.dl.dataset.x[img]).tuple3
  eff_preds[name] = String(Python.str(p.0))!
}
//let stop = DispatchTime.now()
let eff_stop = py_time.time()
//let nanoTime = stop.uptimeNanoseconds - start.uptimeNanoseconds
//let elapsed  = Double(nanoTime) / 1_000_000_000
let eff_elapsed = eff_stop - eff_start
print("Swift Elapsed Time: \(eff_elapsed)")
// Out:
// Swift Elapsed Time: 30.21703839302063

// %%
let eff_pred_list:PythonObject = PythonObject(eff_preds).items()
//print(pred_list)

// %%
let eff_results = pd.DataFrame.dynamicallyCall(withKeywordArguments: ["data": Array(eff_pred_list), "columns": ["file_name", "id"]])
print(eff_results)
// Out:
//                                 file_name                          id
// 0                test_low_capacity_10.jpg       turbines_low_capacity
// 1     test_no_turbines_no_potential_5.jpg    no_turbines_no_potential
// 2                test_high_capacity_5.jpg      turbines_high_capacity
// 3                test_high_capacity_3.jpg      turbines_high_capacity
// 4    test_no_turbines_high_capacity_7.jpg  no_turbines_high_potential
// 5                 test_low_capacity_8.jpg       turbines_low_capacity
// 6                test_high_capacity_4.jpg      turbines_high_capacity
// 7                test_high_capacity_8.jpg      turbines_high_capacity
// 8   test_no_turbines_high_potential_6.jpg  no_turbines_high_potential
// 9                test_high_capacity_1.jpg      turbines_high_capacity
// 10  test_no_turbines_high_potential_9.jpg      turbines_high_capacity
// 11                test_low_capacity_3.jpg       turbines_low_capacity
// 12             test_medium_capacity_9.jpg    turbines_medium_capacity
// 13               test_high_capacity_2.jpg      turbines_high_capacity
// 14  test_no_turbines_high_potential_2.jpg  no_turbines_high_potential
// 15            test_medium_capacity_11.jpg   no_turbines_low_potential
// 16             test_medium_capacity_7.jpg   no_turbines_med_potential
// 17               test_high_capacity_7.jpg      turbines_high_capacity
// 18    test_no_turbines_no_potential_6.jpg    no_turbines_no_potential
// 19    test_no_turbines_no_potential_4.jpg    no_turbines_no_potential
// 20            test_medium_capacity_10.jpg    turbines_medium_capacity
// 21            test_medium_capacity_13.jpg    turbines_medium_capacity
// 22  test_no_turbines_high_potential_8.jpg  no_turbines_high_potential
// 23    test_no_turbines_no_potential_1.jpg    no_turbines_no_potential
// 24             test_medium_capacity_2.jpg    turbines_medium_capacity
// 25             test_medium_capacity_6.jpg    turbines_medium_capacity
// 26             test_medium_capacity_1.jpg    turbines_medium_capacity
// 27             test_medium_capacity_4.jpg   no_turbines_low_potential
// 28                test_low_capacity_1.jpg   no_turbines_low_potential
// 29                test_low_capacity_5.jpg   no_turbines_low_potential
// 30                test_low_capacity_6.jpg       turbines_low_capacity
// 31  test_no_turbines_high_potential_1.jpg  no_turbines_high_potential
// 32                test_low_capacity_7.jpg       turbines_low_capacity
// 33   test_no_turbines_low_potential_2.jpg   no_turbines_low_potential
// 34               test_high_capacity_6.jpg      turbines_high_capacity
// 35   test_no_turbines_med_potential_2.jpg   no_turbines_med_potential
// 36               test_low_capacity_11.jpg       turbines_low_capacity
// 37                test_low_capacity_2.jpg       turbines_low_capacity
// 38            test_medium_capacity_12.jpg    turbines_medium_capacity
// 39                test_low_capacity_4.jpg   no_turbines_low_potential
// 40   test_no_turbines_low_potential_1.jpg   no_turbines_low_potential
// 41             test_medium_capacity_5.jpg    turbines_medium_capacity
// 42    test_no_turbines_no_potential_2.jpg    no_turbines_no_potential
// 43                test_low_capacity_9.jpg       turbines_low_capacity
// 44    test_no_turbines_no_potential_3.jpg    no_turbines_no_potential
// 45             test_medium_capacity_8.jpg      turbines_high_capacity
// 46  test_no_turbines_high_potential_5.jpg  no_turbines_high_potential
// 47   test_no_turbines_med_potential_1.jpg   no_turbines_med_potential
// 48   test_no_turbines_med_potential_3.jpg   no_turbines_med_potential

// %%
inference_test_inceptionv3.model.eval()
var incept_preds:[String:String] = [:]

//let start = DispatchTime.now()
let incept_start = py_time.time()
for img in 0...48 {
  var name = String(test_file_list[img])!
  var p = inference_test_inceptionv3.predict(inference_test_inceptionv3.data.test_dl.dl.dataset.x[img]).tuple3
  incept_preds[name] = String(Python.str(p.0))!
}
//let stop = DispatchTime.now()
//let nanoTime = stop.uptimeNanoseconds - start.uptimeNanoseconds
//let elapsed  = Double(nanoTime) / 1_000_000_000
let incept_stop = py_time.time()
let incept_elapsed = incept_stop - incept_start 
print("Elapsed Time: \(incept_elapsed)")
// Out:
// Elapsed Time: 33.671093225479126

// %%
let incept_pred_list:PythonObject = PythonObject(incept_preds).items()
//print(pred_list)

// %%
let incept_results = pd.DataFrame.dynamicallyCall(withKeywordArguments: ["data": Array(incept_pred_list), "columns": ["file_name", "id"]])
print(incept_results)
// Out:
//                                 file_name                          id
// 0     test_no_turbines_no_potential_5.jpg    no_turbines_no_potential
// 1             test_medium_capacity_10.jpg    turbines_medium_capacity
// 2    test_no_turbines_med_potential_1.jpg   no_turbines_med_potential
// 3                 test_low_capacity_8.jpg       turbines_low_capacity
// 4                test_high_capacity_3.jpg    turbines_medium_capacity
// 5                test_high_capacity_7.jpg    turbines_medium_capacity
// 6     test_no_turbines_no_potential_2.jpg    no_turbines_no_potential
// 7    test_no_turbines_med_potential_3.jpg   no_turbines_med_potential
// 8              test_medium_capacity_1.jpg    turbines_medium_capacity
// 9                 test_low_capacity_2.jpg       turbines_low_capacity
// 10                test_low_capacity_3.jpg       turbines_low_capacity
// 11               test_high_capacity_4.jpg      turbines_high_capacity
// 12            test_medium_capacity_12.jpg    turbines_medium_capacity
// 13                test_low_capacity_1.jpg       turbines_low_capacity
// 14  test_no_turbines_high_potential_6.jpg  no_turbines_high_potential
// 15               test_high_capacity_1.jpg    turbines_medium_capacity
// 16  test_no_turbines_high_potential_8.jpg  no_turbines_high_potential
// 17               test_low_capacity_11.jpg   no_turbines_low_potential
// 18             test_medium_capacity_4.jpg    turbines_medium_capacity
// 19    test_no_turbines_no_potential_1.jpg    no_turbines_no_potential
// 20    test_no_turbines_no_potential_6.jpg    no_turbines_no_potential
// 21  test_no_turbines_high_potential_1.jpg  no_turbines_high_potential
// 22             test_medium_capacity_8.jpg      turbines_high_capacity
// 23   test_no_turbines_high_capacity_7.jpg  no_turbines_high_potential
// 24               test_low_capacity_10.jpg    turbines_medium_capacity
// 25                test_low_capacity_5.jpg   no_turbines_low_potential
// 26                test_low_capacity_9.jpg   no_turbines_low_potential
// 27   test_no_turbines_med_potential_2.jpg    turbines_medium_capacity
// 28  test_no_turbines_high_potential_2.jpg  no_turbines_high_potential
// 29               test_high_capacity_2.jpg      turbines_high_capacity
// 30            test_medium_capacity_13.jpg    turbines_medium_capacity
// 31    test_no_turbines_no_potential_3.jpg    no_turbines_no_potential
// 32             test_medium_capacity_2.jpg    turbines_medium_capacity
// 33   test_no_turbines_low_potential_1.jpg   no_turbines_med_potential
// 34                test_low_capacity_7.jpg       turbines_low_capacity
// 35             test_medium_capacity_5.jpg      turbines_high_capacity
// 36                test_low_capacity_4.jpg  no_turbines_high_potential
// 37   test_no_turbines_low_potential_2.jpg   no_turbines_low_potential
// 38             test_medium_capacity_9.jpg    turbines_medium_capacity
// 39  test_no_turbines_high_potential_9.jpg      turbines_high_capacity
// 40                test_low_capacity_6.jpg       turbines_low_capacity
// 41               test_high_capacity_8.jpg    turbines_medium_capacity
// 42             test_medium_capacity_6.jpg    turbines_medium_capacity
// 43             test_medium_capacity_7.jpg   no_turbines_med_potential
// 44    test_no_turbines_no_potential_4.jpg    no_turbines_no_potential
// 45               test_high_capacity_5.jpg      turbines_high_capacity
// 46               test_high_capacity_6.jpg    turbines_medium_capacity
// 47  test_no_turbines_high_potential_5.jpg  no_turbines_high_potential
// 48            test_medium_capacity_11.jpg    turbines_medium_capacity
